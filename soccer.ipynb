# %% [markdown]
# Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install plotly
import plotly.graph_objects as go

# %% [markdown]
# EDA

# %%
df = pd.read_csv("soccer_data.csv")
df
# Out:
#    Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0     10/8/18      Man United       Leicester     2     1   H     1
# 1   E0     11/8/18     Bournemouth         Cardiff     2     0   H     1
# 2   E0     11/8/18          Fulham  Crystal Palace     0     2   A     0
# 3   E0     11/8/18    Huddersfield         Chelsea     0     3   A     0
# 4   E0     11/8/18       Newcastle       Tottenham     1     2   A     1
# ..  ..         ...             ...             ...   ...   ...  ..   ...
# 95  E0  27/10/2018         Watford    Huddersfield     3     0   H     2
# 96  E0  28/10/2018         Burnley         Chelsea     0     4   A     0
# 97  E0  28/10/2018  Crystal Palace         Arsenal     2     2   D     1
# 98  E0  28/10/2018      Man United         Everton     2     1   H     1
# 99  E0  29/10/2018       Tottenham        Man City     0     1   A     0
#
#     HTAG HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# ...

# %%
FTHG_des = df["FTHG"].describe()  #Full_Time_Home_Goals
FTHG_des
# Out:
# count    100.000000
# mean       1.470000
# std        1.359256
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        6.000000
# Name: FTHG, dtype: float64

# %%
FTAG_des = df["FTAG"].describe()  #Full_Time_Away_Goals
FTAG_des
# Out:
# count    100.000000
# mean       1.300000
# std        1.141504
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000
# Name: FTAG, dtype: float64

# %%
HS_des = df["HS"].describe()  #Number of shots taken by home team
HS_des
# Out:
# count    100.000000
# mean      14.160000
# std        6.546986
# min        2.000000
# 25%        9.000000
# 50%       13.000000
# 75%       19.000000
# max       32.000000
# Name: HS, dtype: float64

# %%
AS_des = df["AS"].describe()   #Number of shots taken by away team
AS_des
# Out:
# count    100.000000
# mean      11.240000
# std        4.682053
# min        2.000000
# 25%        8.000000
# 50%       10.000000
# 75%       14.000000
# max       25.000000
# Name: AS, dtype: float64

# %%
HF_des = df["HF"].describe()  #Number of fouls made by home team
HF_des
# Out:
# count    100.000000
# mean      11.060000
# std        3.212413
# min        4.000000
# 25%        9.000000
# 50%       11.000000
# 75%       13.000000
# max       23.000000
# Name: HF, dtype: float64

# %%
AF_des = df["AF"].describe()  #Number of fouls made by away team
AF_des
# Out:
# count    100.000000
# mean      11.120000
# std        3.635626
# min        3.000000
# 25%        9.000000
# 50%       11.000000
# 75%       13.000000
# max       20.000000
# Name: AF, dtype: float64

# %%
HY_des = df["HY"].describe()  #Number of yellow cards received by home team
HY_des
# Out:
# count    100.000000
# mean       1.600000
# std        1.239094
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        6.000000
# Name: HY, dtype: float64

# %%
AY_des = df["AY"].describe()  #Number of yellow cards received by away team
AY_des
# Out:
# count    100.000000
# mean       1.680000
# std        1.171031
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        5.000000
# Name: AY, dtype: float64

# %%
HR_des = df["HR"].describe()  #Number of red cards received by home team
HR_des
# Out:
# count    100.00000
# mean       0.08000
# std        0.27266
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max        1.00000
# Name: HR, dtype: float64

# %%
AR_des = df["AR"].describe()  #Number of red cards received by away team
AR_des
# Out:
# count    100.00000
# mean       0.08000
# std        0.27266
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max        1.00000
# Name: AR, dtype: float64

# %%
col_of_interest = ['FTHG', 'FTAG', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR']
corr_data = df[col_of_interest].corr()
corr_data
# Out:
#           FTHG      FTAG        HS        AS       HST       AST        HF  \
# FTHG  1.000000 -0.235014  0.405764 -0.302009  0.660078 -0.321482  0.014296
# FTAG -0.235014  1.000000 -0.167327  0.266106 -0.175712  0.478374  0.146544
# HS    0.405764 -0.167327  1.000000 -0.513016  0.741357 -0.390579 -0.160393
# AS   -0.302009  0.266106 -0.513016  1.000000 -0.330888  0.658138  0.177001
# HST   0.660078 -0.175712  0.741357 -0.330888  1.000000 -0.265830 -0.098227
# AST  -0.321482  0.478374 -0.390579  0.658138 -0.265830  1.000000  0.146896
# HF    0.014296  0.146544 -0.160393  0.177001 -0.098227  0.146896  1.000000
# AF   -0.160741  0.037483 -0.004634 -0.123356 -0.126610  0.100478  0.048675
# HY   -0.157131  0.242808 -0.229853  0.324890 -0.174190  0.242367  0.346133
# AY    0.019292  0.042316  0.151672 -0.140604  0.048033 -0.061101  0.010526
# HR   -0.156987  0.149288 -0.188315  0.071844 -0.228151  0.095698 -0.028600
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_data, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Match Statistics')
plt.show()

# %%
total_shots_HT = df.groupby("HomeTeam")["HS"].sum()

total_shots_ontarget_HT = df.groupby("HomeTeam")["HST"].sum()

total_goals_HT = df.groupby("HomeTeam")["FTHG"].sum()   # Total goals scored by each team home

total_shots_AT = df.groupby("AwayTeam")["AS"].sum()

total_shots_ontarget_AT = df.groupby("AwayTeam")["AST"].sum()

total_goals_AT = df.groupby("AwayTeam")["FTAG"].sum()   # Total goals scored by each team away

offensive_df['Total Goals'] = total_goals_HT  + total_goals_AT  # Total goals scored by each team (home and away)

offensive_df['Total Shots'] = total_shots_HT + total_shots_AT   # Total shots taken by each team (home and away)

Goals = pd.DataFrame({"Home Team Shots" : total_shots_HT , "Home Team Shots On Target" : total_shots_ontarget_HT , 
                      "Home Team Goals" : total_goals_HT , "Away Team Shots" : total_shots_AT ,"Away Team Shots On Target" : total_shots_ontarget_AT 
                       , "Away Team Goals" : total_goals_AT})
Goals
# Out:
#                 Home Team Shots  Home Team Shots On Target  Home Team Goals  \
# Arsenal                      63                         26               10
# Bournemouth                  60                         21               10
# Brighton                     40                         17                8
# Burnley                      42                         14                6
# Cardiff                      69                         16                7
# Chelsea                      97                         34               12
# Crystal Palace               71                         19                2
# Everton                      79                         22                9
# Fulham                       87                         26                6
# Huddersfield                 48                         10                0
# Leicester                    65                         24                8
# ...

# %%
plt.figure(figsize=(14, 6))
plt.bar(offensive_metrics['HomeTeam'], offensive_metrics['Total Goals'], label='Total Goals', color='blue')
plt.bar(offensive_metrics['HomeTeam'], offensive_metrics['Total Shots'], label='Total Shots', color='orange', alpha=0.6)
plt.xlabel('Teams')
plt.ylabel('Counts')
plt.title('Offensive Metrics: Goals and Shots per Team')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
offensive_df = pd.DataFrame()

# Total goals scored by each team (home and away)
offensive_df['Total Goals'] = total_goals_HT  + total_goals_AT

# Total shots taken by each team (home and away)
offensive_df['Total Shots'] = total_shots_HT + total_shots_AT

# Reset the index to get team names as a column
offensive_df = offensive_df.reset_index()

# Rank teams based on Total Goals and Total Shots
offensive_df['Goal Rank'] = offensive_df['Total Goals'].rank(ascending=False)
offensive_df['Shots Rank'] = offensive_df['Total Shots'].rank(ascending=False)

# Sort the dataframe by total goals
offensive_df_sorted = offensive_df.sort_values(by='Total Goals', ascending=False)

offensive_df_sorted[['HomeTeam', 'Total Goals', 'Total Shots', 'Goal Rank', 'Shots Rank']]
# Out:
#           HomeTeam  Total Goals  Total Shots  Goal Rank  Shots Rank
# 12        Man City           27          211        1.0         1.0
# 0          Arsenal           24          123        2.5        10.0
# 5          Chelsea           24          187        2.5         2.0
# 11       Liverpool           20          145        4.0         4.5
# 1      Bournemouth           19          121        5.0        11.5
# 13      Man United           17          133        6.0         7.0
# 17         Watford           16          121        8.5        11.5
# 16       Tottenham           16          130        8.5         9.0
# 10       Leicester           16          120        8.5        13.0
# 7          Everton           16          136        8.5         6.0
# 8           Fulham           11          131       11.5         8.0
# 2         Brighton           11           76       11.5        20.0
# 3          Burnley           10           85       13.0        19.0
# ...

# %%
H_Y_T_F = df.groupby("HomeTeam")["HY"].sum()  # total yellow cards by home team
A_Y_T_F = df.groupby("AwayTeam")["AY"].sum()  # total yellow cards by away team
H_R_T_F = df.groupby("HomeTeam")["HR"].sum()  # total red cards by home team
A_R_T_F = df.groupby("AwayTeam")["AR"].sum()  # total red cards by away team
H_T_T_F = df.groupby("HomeTeam")["HF"].sum()  # total fouls made by home team
A_T_T_F = df.groupby("HomeTeam")["AF"].sum()  # total fouls made by away team

Cards_fouls = pd.DataFrame({"Total Home Team Yellow| card |" : H_Y_T_F , "Total Away Team Yellow| card |" : A_Y_T_F , 
                             "Total Home Team Red| card |" : H_R_T_F , "Total Away Team Red| card |" : A_R_T_F , 
                            "Total Home Team| Fouls |" : H_T_T_F , "Total Away Team| Fouls |" : A_T_T_F})
Cards_fouls
# Out:
#                 Total Home Team Yellow| card |  \
# Arsenal                                      9
# Bournemouth                                  8
# Brighton                                    12
# Burnley                                     11
# Cardiff                                     10
# Chelsea                                      4
# Crystal Palace                               7
# Everton                                      7
# Fulham                                       9
# Huddersfield                                 5
# Leicester                                   10
# Liverpool                                    3
# Man City                                     2
# Man United                                   9
# Newcastle                                    5
# Southampton                                  9
# Tottenham                                    4
# Watford                                     14
# West Ham                                    13
# ...

# %%
defensive_metrics = pd.DataFrame()
defensive_metrics['Total Fouls'] = H_T_T_F + A_T_T_F
defensive_metrics['Total Yellow Cards'] = H_Y_T_F + A_Y_T_F
defensive_metrics['Total Red Cards'] = H_R_T_F + A_R_T_F
defensive_metrics = defensive_metrics.reset_index()
plt.figure(figsize=(14, 6))
plt.bar(defensive_metrics['HomeTeam'], defensive_metrics['Total Fouls'], label='Total Fouls', color='red')
plt.bar(defensive_metrics['HomeTeam'], defensive_metrics['Total Yellow Cards'], label='Yellow Cards', color='yellow', alpha=0.6)
plt.bar(defensive_metrics['HomeTeam'], defensive_metrics['Total Red Cards'], label='Red Cards', color='brown', alpha=0.6)
plt.xlabel('Teams')
plt.ylabel('Counts')
plt.title('Defensive Metrics: Fouls and Cards per Team')
plt.xticks(rotation=90)
plt.legend()
plt.show()
